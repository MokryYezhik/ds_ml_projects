# %% [markdown]
# В одной компании произошла неприятность: случился потоп, в бумажных анкетах клиентов размыло некоторые строки и в 1000 анкетах пострадало поле “gender”. Конечно, их было бы можно восстановить, но в компании решили автоматизировать решение проблемы и определить пол клиентов по фотографиям. Был создан датасет gender.csv, в котором записаны признаки человека на фото и его пол.
#
# Первые 1000 значений имеют пропуски в столбце gender.
#
# Все столбцы с ".1" в названии дублируют предыдущие столбцы без ".1", но содержат уникальные значения
#
# Необходимо произвести чистку данных.
#
# Определите пол по остальным параметрам из выборки для первой тысячи значений и прикрепите его в CSV формате. Файл должен содержать только прогнозные значения в формате "Male"/"Female", в одном столбце без заголовка.
#
# Пороговое значение для данной задачи классификации считать равным 0.5.

# %% [markdown]
# Поля
# - index	индексы записей
# - long_hair	длинные волосы у человека или нет
# - forehead_width_cm	ширина лба справа налево в см.
# - forehead_height_cm	ширина лба в см от места роста волос до бровей.
# - forehead_width_mm	ширина лба справа налево в мм.
# - forehead_width_conventional_units	ширина лба справа налево в стандартизованном виде. Значения forehead_width_mm преобразованы в диапазон от 0 до 1.
# - nose_wide	широкий нос или нет. 1 означает широкий, а 0 - нет.
# - nose_long	длинный нос или нет. 1 означает длинный, а 0 - нет.
# - lips_thin	есть ли у этого человека тонкая губа или нет. 1 означает тонкая, а 0 - нет.
# - distance_nose_to_lip_long	расстояние от носа до губы. 1 означает большое, а 0 - небольшое.
# - gender	Либо мужчина ("Male"), либо женщина ("Female")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Данные

# %%
data = pd.read_csv('gender(1).csv')

# %%
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#       Unnamed: 0  index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0              0      0   0.704275               11.8                 6.1
# 1              1      1   0.118690               14.0                 5.4
# 2              2      2   0.203894               11.8                 6.3
# 3              3      3   0.386228               14.4                 6.1
# 4              4      4   0.564020               13.5                 5.9
# ...          ...    ...        ...                ...                 ...
# 2510        2510   2510   0.915744               13.9                 6.4
# 2511        2511   2511   0.820041               13.8                 5.1
# 2512        2512   2512   0.659143               12.2                 5.3
# 2513        2513   2513   0.664928               12.1                 5.2
# 2514        2514   2514   0.561345               12.2                 5.8
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 0                 118.0                           0.025806   0.895614
# 1                 140.0                           0.167742   0.202520
# 2                 118.0                           0.025806   0.892793
# 3                 144.0                           0.193548   0.024963
# 4                 135.0                           0.135484   0.415389
# ...                 ...                                ...        ...
# 2510              139.0                           0.161290   0.604791
# 2511              138.0                           0.154839   0.933549
# 2512              122.0                           0.051613   0.531385
# 2513              121.0                           0.045161   0.538634
# 2514              122.0                           0.051613   0.940424
#
#       nose_long  lips_thin  distance_nose_to_lip_long  gender  index.1  \
# 0      0.477485   0.841261                   0.902628     NaN     2515
# 1      0.186825   0.719697                   0.309122     NaN     2516
# 2      0.723152   0.725821                   0.720640     NaN     2517
# 3      0.562005   0.831515                   0.770379     NaN     2518
# 4      0.063705   0.211584                   0.157217     NaN     2519
# ...         ...        ...                        ...     ...      ...
# 2510   0.851645   0.766959                   0.763820    Male     4996
# 2511   0.537350   0.918460                   0.938982    Male     4997
# 2512   0.456792   0.489438                   0.457138  Female     4998
# 2513   0.610885   0.977585                   0.942940    Male     4999
# 2514   0.873414   0.561728                   0.815824    Male     5000
#
#       long_hair.1  forehead_width_cm.1  forehead_height_cm.1  \
# 0        0.818018                 11.5                   5.8
# 1        0.995941                 15.2                   5.8
# 2        0.633806                 15.4                   5.7
# 3        0.795792                 13.0                   6.9
# 4        0.915185                 14.2                   5.8
# ...           ...                  ...                   ...
# 2510     0.645930                 13.6                   5.1
# 2511     0.501251                 11.9                   5.4
# 2512     0.701357                 12.9                   5.7
# 2513     0.684078                 13.2                   6.2
# 2514     0.794726                 15.4                   5.4
#
#       forehead_width_mm.1  forehead_width_conventional_units.1  nose_wide.1  \
# 0                   115.0                             0.006452     0.137806
# 1                   152.0                             0.245161     0.570656
# 2                   154.0                             0.258065     0.709777
# 3                   130.0                             0.103226     0.883454
# 4                   142.0                             0.180645     0.652973
# ...                   ...                                  ...          ...
# 2510                136.0                             0.141935     0.443641
# 2511                119.0                             0.032258     0.473038
# 2512                129.0                             0.096774     0.388300
# 2513                132.0                             0.116129     0.067981
# 2514                154.0                             0.258065     0.812078
#
#       nose_long.1  lips_thin.1  distance_nose_to_lip_long.1 gender.1
# 0        0.402620     0.167844                     0.188913   Female
# 1        0.980237     0.811487                     0.967540     Male
# 2        0.365825     0.933026                     0.646992     Male
# 3        0.399733     0.595028                     0.822491     Male
# 4        0.735543     0.553571                     0.532910     Male
# ...           ...          ...                          ...      ...
# 2510     0.255464     0.116379                     0.042459   Female
# 2511     0.469482     0.067636                     0.210801   Female
# 2512     0.428321     0.322559                     0.199743   Female
# 2513     0.167563     0.218222                     0.370723   Female
# 2514     0.956397     0.692107                     0.531950     Male
#
# [2515 rows x 23 columns]

# %%
np.array_equal(data.index.values, data['Unnamed: 0'].values)
# Out:
# True

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   index                                2515 non-null   int64
#  1   long_hair                            2515 non-null   float64
#  2   forehead_width_cm                    2515 non-null   float64
#  3   forehead_height_cm                   2515 non-null   float64
#  4   forehead_width_mm                    2515 non-null   float64
#  5   forehead_width_conventional_units    2515 non-null   float64
#  6   nose_wide                            2515 non-null   float64
#  7   nose_long                            2515 non-null   float64
#  8   lips_thin                            2515 non-null   float64
#  9   distance_nose_to_lip_long            2515 non-null   float64
#  10  gender                               1514 non-null   object
#  11  index.1                              2515 non-null   int64
#  12  long_hair.1                          2486 non-null   float64
#  13  forehead_width_cm.1                  2486 non-null   float64
#  14  forehead_height_cm.1                 2486 non-null   float64
#  15  forehead_width_mm.1                  2486 non-null   float64
#  16  forehead_width_conventional_units.1  2486 non-null   float64
#  17  nose_wide.1                          2486 non-null   float64
#  18  nose_long.1                          2486 non-null   float64
#  19  lips_thin.1                          2486 non-null   float64
#  20  distance_nose_to_lip_long.1          2486 non-null   float64
#  21  gender.1                             2486 non-null   object
# dtypes: float64(18), int64(2), object(2)
# memory usage: 432.4+ KB

# %% [markdown]
# Объеденим данные в одну таблицу

# %%
df1 = data.iloc[:, :11]
df1.head()
# Out:
#    index  long_hair  forehead_width_cm  forehead_height_cm  forehead_width_mm  \
# 0      0   0.704275               11.8                 6.1              118.0
# 1      1   0.118690               14.0                 5.4              140.0
# 2      2   0.203894               11.8                 6.3              118.0
# 3      3   0.386228               14.4                 6.1              144.0
# 4      4   0.564020               13.5                 5.9              135.0
#
#    forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 0                           0.025806   0.895614   0.477485   0.841261
# 1                           0.167742   0.202520   0.186825   0.719697
# 2                           0.025806   0.892793   0.723152   0.725821
# 3                           0.193548   0.024963   0.562005   0.831515
# 4                           0.135484   0.415389   0.063705   0.211584
#
#    distance_nose_to_lip_long gender
# 0                   0.902628    NaN
# 1                   0.309122    NaN
# 2                   0.720640    NaN
# 3                   0.770379    NaN
# 4                   0.157217    NaN

# %%
df2 = data.iloc[:, 11:]
df2.columns = df1.columns
df2.tail()
# Out:
#       index  long_hair  forehead_width_cm  forehead_height_cm  \
# 2510   4996   0.645930               13.6                 5.1
# 2511   4997   0.501251               11.9                 5.4
# 2512   4998   0.701357               12.9                 5.7
# 2513   4999   0.684078               13.2                 6.2
# 2514   5000   0.794726               15.4                 5.4
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 2510              136.0                           0.141935   0.443641
# 2511              119.0                           0.032258   0.473038
# 2512              129.0                           0.096774   0.388300
# 2513              132.0                           0.116129   0.067981
# 2514              154.0                           0.258065   0.812078
#
#       nose_long  lips_thin  distance_nose_to_lip_long  gender
# 2510   0.255464   0.116379                   0.042459  Female
# 2511   0.469482   0.067636                   0.210801  Female
# 2512   0.428321   0.322559                   0.199743  Female
# 2513   0.167563   0.218222                   0.370723  Female
# 2514   0.956397   0.692107                   0.531950    Male

# %%
df = pd.concat([df1, df2], axis=0, ignore_index=True)
df
# Out:
#       index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0         0   0.704275               11.8                 6.1
# 1         1   0.118690               14.0                 5.4
# 2         2   0.203894               11.8                 6.3
# 3         3   0.386228               14.4                 6.1
# 4         4   0.564020               13.5                 5.9
# ...     ...        ...                ...                 ...
# 5025   4996   0.645930               13.6                 5.1
# 5026   4997   0.501251               11.9                 5.4
# 5027   4998   0.701357               12.9                 5.7
# 5028   4999   0.684078               13.2                 6.2
# 5029   5000   0.794726               15.4                 5.4
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 0                 118.0                           0.025806   0.895614
# 1                 140.0                           0.167742   0.202520
# 2                 118.0                           0.025806   0.892793
# 3                 144.0                           0.193548   0.024963
# 4                 135.0                           0.135484   0.415389
# ...                 ...                                ...        ...
# 5025              136.0                           0.141935   0.443641
# 5026              119.0                           0.032258   0.473038
# 5027              129.0                           0.096774   0.388300
# 5028              132.0                           0.116129   0.067981
# 5029              154.0                           0.258065   0.812078
#
#       nose_long  lips_thin  distance_nose_to_lip_long  gender
# 0      0.477485   0.841261                   0.902628     NaN
# 1      0.186825   0.719697                   0.309122     NaN
# 2      0.723152   0.725821                   0.720640     NaN
# 3      0.562005   0.831515                   0.770379     NaN
# 4      0.063705   0.211584                   0.157217     NaN
# ...         ...        ...                        ...     ...
# 5025   0.255464   0.116379                   0.042459  Female
# 5026   0.469482   0.067636                   0.210801  Female
# 5027   0.428321   0.322559                   0.199743  Female
# 5028   0.167563   0.218222                   0.370723  Female
# 5029   0.956397   0.692107                   0.531950    Male
#
# [5030 rows x 11 columns]

# %% [markdown]
# Удалим строки, в которых только NaN

# %%
df.isnull().sum(axis=1).value_counts()
# Out:
# 0     4000
# 1     1001
# 10      29
# dtype: int64

# %%
idx_null = df.isnull().sum(axis=1)[df.isnull().sum(axis=1) == 10].index
idx_null
# Out:
# Int64Index([3000, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010,
#             3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021,
#             3022, 3023, 3024, 3025, 3026, 3027, 3028],
#            dtype='int64')

# %%
df.iloc[idx_null]
# Out:
#       index  long_hair  forehead_width_cm  forehead_height_cm  \
# 3000      0        NaN                NaN                 NaN
# 3001      1        NaN                NaN                 NaN
# 3002      2        NaN                NaN                 NaN
# 3003      3        NaN                NaN                 NaN
# 3004      4        NaN                NaN                 NaN
# 3005      5        NaN                NaN                 NaN
# 3006      6        NaN                NaN                 NaN
# 3007      7        NaN                NaN                 NaN
# 3008      8        NaN                NaN                 NaN
# 3009      9        NaN                NaN                 NaN
# 3010     10        NaN                NaN                 NaN
# 3011     11        NaN                NaN                 NaN
# 3012     12        NaN                NaN                 NaN
# 3013     13        NaN                NaN                 NaN
# 3014     14        NaN                NaN                 NaN
# 3015     15        NaN                NaN                 NaN
# 3016     16        NaN                NaN                 NaN
# 3017     17        NaN                NaN                 NaN
# 3018     18        NaN                NaN                 NaN
# 3019     19        NaN                NaN                 NaN
# 3020     20        NaN                NaN                 NaN
# 3021     21        NaN                NaN                 NaN
# 3022     22        NaN                NaN                 NaN
# 3023     23        NaN                NaN                 NaN
# 3024     24        NaN                NaN                 NaN
# 3025     25        NaN                NaN                 NaN
# 3026     26        NaN                NaN                 NaN
# 3027     27        NaN                NaN                 NaN
# 3028     28        NaN                NaN                 NaN
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 3000                NaN                                NaN        NaN
# 3001                NaN                                NaN        NaN
# 3002                NaN                                NaN        NaN
# 3003                NaN                                NaN        NaN
# 3004                NaN                                NaN        NaN
# 3005                NaN                                NaN        NaN
# 3006                NaN                                NaN        NaN
# 3007                NaN                                NaN        NaN
# 3008                NaN                                NaN        NaN
# 3009                NaN                                NaN        NaN
# 3010                NaN                                NaN        NaN
# 3011                NaN                                NaN        NaN
# 3012                NaN                                NaN        NaN
# 3013                NaN                                NaN        NaN
# 3014                NaN                                NaN        NaN
# 3015                NaN                                NaN        NaN
# 3016                NaN                                NaN        NaN
# 3017                NaN                                NaN        NaN
# 3018                NaN                                NaN        NaN
# 3019                NaN                                NaN        NaN
# 3020                NaN                                NaN        NaN
# 3021                NaN                                NaN        NaN
# 3022                NaN                                NaN        NaN
# 3023                NaN                                NaN        NaN
# 3024                NaN                                NaN        NaN
# 3025                NaN                                NaN        NaN
# 3026                NaN                                NaN        NaN
# 3027                NaN                                NaN        NaN
# 3028                NaN                                NaN        NaN
#
#       nose_long  lips_thin  distance_nose_to_lip_long gender
# 3000        NaN        NaN                        NaN    NaN
# 3001        NaN        NaN                        NaN    NaN
# 3002        NaN        NaN                        NaN    NaN
# 3003        NaN        NaN                        NaN    NaN
# 3004        NaN        NaN                        NaN    NaN
# 3005        NaN        NaN                        NaN    NaN
# 3006        NaN        NaN                        NaN    NaN
# 3007        NaN        NaN                        NaN    NaN
# 3008        NaN        NaN                        NaN    NaN
# 3009        NaN        NaN                        NaN    NaN
# 3010        NaN        NaN                        NaN    NaN
# 3011        NaN        NaN                        NaN    NaN
# 3012        NaN        NaN                        NaN    NaN
# 3013        NaN        NaN                        NaN    NaN
# 3014        NaN        NaN                        NaN    NaN
# 3015        NaN        NaN                        NaN    NaN
# 3016        NaN        NaN                        NaN    NaN
# 3017        NaN        NaN                        NaN    NaN
# 3018        NaN        NaN                        NaN    NaN
# 3019        NaN        NaN                        NaN    NaN
# 3020        NaN        NaN                        NaN    NaN
# 3021        NaN        NaN                        NaN    NaN
# 3022        NaN        NaN                        NaN    NaN
# 3023        NaN        NaN                        NaN    NaN
# 3024        NaN        NaN                        NaN    NaN
# 3025        NaN        NaN                        NaN    NaN
# 3026        NaN        NaN                        NaN    NaN
# 3027        NaN        NaN                        NaN    NaN
# 3028        NaN        NaN                        NaN    NaN

# %%
df = df.drop(idx_null, axis=0)
df.shape
# Out:
# (5001, 11)

# %%
df.isnull().sum(axis=1).value_counts()
# Out:
# 0    4000
# 1    1001
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5001 entries, 0 to 5029
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              5001 non-null   int64
#  1   long_hair                          5001 non-null   float64
#  2   forehead_width_cm                  5001 non-null   float64
#  3   forehead_height_cm                 5001 non-null   float64
#  4   forehead_width_mm                  5001 non-null   float64
#  5   forehead_width_conventional_units  5001 non-null   float64
#  6   nose_wide                          5001 non-null   float64
#  7   nose_long                          5001 non-null   float64
#  8   lips_thin                          5001 non-null   float64
#  9   distance_nose_to_lip_long          5001 non-null   float64
#  10  gender                             4000 non-null   object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 468.8+ KB

# %% [markdown]
# датасет сбалансированный

# %%
df['gender'].value_counts()
# Out:
# Female    2006
# Male      1994
# Name: gender, dtype: int64

# %% [markdown]
# # Обработка признаков

# %%
def hist_by_sex(feature, df=df):
    plt.figure(figsize=(20,6))
    plt.subplot(1,2,1)
    df[df['gender']=='Male'][feature].hist()
    plt.title('Male')
    plt.subplot(1,2,2)
    df[df['gender']=='Female'][feature].hist()
    plt.title('Female')
    plt.show()

# %%
hist_by_sex('long_hair')

# %%
hist_by_sex('forehead_width_cm')

# %%
hist_by_sex('forehead_width_conventional_units')

# %%
hist_by_sex('forehead_height_cm')

# %%
hist_by_sex('nose_wide')

# %%
hist_by_sex('nose_long')

# %%
hist_by_sex('lips_thin')

# %%
hist_by_sex('distance_nose_to_lip_long')

# %% [markdown]
# Из гистограмм признаков видно, что некоторые признаки имеют почти равномерное распределение при значениях больше или меньше 0.5. Имеет смысл привести их к 0 или 1.

# %%
feats_0_1 = ['long_hair', 'nose_wide', 'nose_long', 'lips_thin', 'distance_nose_to_lip_long']
for feat in feats_0_1:
    df[feat+'_'] = df[feat].apply(lambda x: 0 if x<0.5 else 1)

# %%
df = df.drop('forehead_width_mm', axis=1)

# %%
df.head()
# Out:
#    index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0      0   0.704275               11.8                 6.1
# 1      1   0.118690               14.0                 5.4
# 2      2   0.203894               11.8                 6.3
# 3      3   0.386228               14.4                 6.1
# 4      4   0.564020               13.5                 5.9
#
#    forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 0                           0.025806   0.895614   0.477485   0.841261
# 1                           0.167742   0.202520   0.186825   0.719697
# 2                           0.025806   0.892793   0.723152   0.725821
# 3                           0.193548   0.024963   0.562005   0.831515
# 4                           0.135484   0.415389   0.063705   0.211584
#
#    distance_nose_to_lip_long gender  long_hair_  nose_wide_  nose_long_  \
# 0                   0.902628    NaN           1           1           0
# 1                   0.309122    NaN           0           0           0
# 2                   0.720640    NaN           0           1           1
# 3                   0.770379    NaN           0           0           1
# 4                   0.157217    NaN           1           0           0
#
#    lips_thin_  distance_nose_to_lip_long_
# 0           1                           1
# 1           1                           0
# 2           1                           1
# 3           1                           1
# 4           0                           0

# %%
feats_0_1_ = [x+'_' for x in feats_0_1]
feats_0_1_
# Out:
# ['long_hair_',
#  'nose_wide_',
#  'nose_long_',
#  'lips_thin_',
#  'distance_nose_to_lip_long_']

# %% [markdown]
# В качестве нового признака возьмем среднее всех пирзнаков, которые до этого привели к 0/1.

# %%
df['0-1_mean'] = df[feats_0_1_[1:]].mean(axis=1)
hist_by_sex('0-1_mean', df)

# %% [markdown]
# Оставшиеся количественные признаки 'forehead_width_cm', 'forehead_height_cm' стандартизируем.

# %%
for feat in ['forehead_width_cm', 'forehead_height_cm']:
    df[feat+'_norm'] = (df[feat]-df[feat].mean())/df[feat].std()
df.head()
# Out:
#    index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0      0   0.704275               11.8                 6.1
# 1      1   0.118690               14.0                 5.4
# 2      2   0.203894               11.8                 6.3
# 3      3   0.386228               14.4                 6.1
# 4      4   0.564020               13.5                 5.9
#
#    forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 0                           0.025806   0.895614   0.477485   0.841261
# 1                           0.167742   0.202520   0.186825   0.719697
# 2                           0.025806   0.892793   0.723152   0.725821
# 3                           0.193548   0.024963   0.562005   0.831515
# 4                           0.135484   0.415389   0.063705   0.211584
#
#    distance_nose_to_lip_long gender  long_hair_  nose_wide_  nose_long_  \
# 0                   0.902628    NaN           1           1           0
# 1                   0.309122    NaN           0           0           0
# 2                   0.720640    NaN           0           1           1
# 3                   0.770379    NaN           0           0           1
# 4                   0.157217    NaN           1           0           0
#
#    lips_thin_  distance_nose_to_lip_long_  0-1_mean  forehead_width_norm  \
# 0           1                           1      0.75            -1.247808
# 1           1                           0      0.25             0.739315
# 2           1                           1      1.00            -1.247808
# 3           1                           1      0.75             1.100610
# 4           0                           0      0.00             0.287696
#
#    forehead_width_cm_norm  forehead_height_cm_norm
# 0               -1.247808                 0.283943
# 1                0.739315                -1.009317
# 2               -1.247808                 0.653446
# 3                1.100610                 0.283943
# 4                0.287696                -0.085560

# %% [markdown]
# Зависимую категориальную переменную пол переведем в численные значения 0/1.

# %%
df['gender_0-1'] = df['gender'].map({'Male': 1, 'Female': 0, None: None})

# %%
df.iloc[1100:1105]
# Out:
#       index  long_hair  forehead_width_cm  forehead_height_cm  \
# 1100   1100   0.515702               12.1                 5.9
# 1101   1101   0.969869               14.3                 5.1
# 1102   1102   0.922619               15.4                 6.9
# 1103   1103   0.883432               11.9                 5.5
# 1104   1104   0.759919               14.0                 7.0
#
#       forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 1100                           0.045161   0.476678   0.104198   0.071598
# 1101                           0.187097   0.914139   0.296687   0.654716
# 1102                           0.258065   0.603979   0.718473   0.491502
# 1103                           0.032258   0.346971   0.138184   0.214530
# 1104                           0.167742   0.501372   0.049477   0.393862
#
#       distance_nose_to_lip_long  gender  long_hair_  nose_wide_  nose_long_  \
# 1100                   0.326367  Female           1           0           0
# 1101                   0.516043    Male           1           1           0
# 1102                   0.664591    Male           1           1           1
# 1103                   0.289670  Female           1           0           0
# 1104                   0.875229    Male           1           1           0
#
#       lips_thin_  distance_nose_to_lip_long_  0-1_mean  forehead_width_norm  \
# 1100           0                           0      0.00            -0.976837
# 1101           1                           1      0.75             1.010286
# 1102           0                           1      0.75             2.003848
# 1103           0                           0      0.00            -1.157484
# 1104           0                           1      0.50             0.739315
#
#       forehead_width_cm_norm  forehead_height_cm_norm  gender_0-1
# 1100               -0.976837                -0.085560         0.0
# 1101                1.010286                -1.563571         1.0
# 1102                2.003848                 1.761954         1.0
# 1103               -1.157484                -0.824565         0.0
# 1104                0.739315                 1.946706         1.0

# %% [markdown]
# ## Моделирование

# %% [markdown]
# Построим простейшую линейную регрессию над тремя признаками.

# %%
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# %%
df_train = df[~df['gender'].isnull()].copy()
df_test = df[df['gender'].isnull()].copy()

# %%
features = ['0-1_mean', 'forehead_width_norm', 'forehead_height_cm_norm']

# %%
sns.heatmap(df[features+['gender_0-1']].corr(method='pearson'), center=0, square=True, cmap="BrBG")
plt.show()

# %% [markdown]
# По матрице корреляций видно, что с таргетом неплохо коррелируют все переменные, особенно '0-1_mean'. При этом между собой признаки не скоррелированны.

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train[features].values, df_train['gender_0-1'].values, test_size=0.2)
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (3200, 3)
# (800, 3)
# (3200,)
# (800,)

# %%
lr = LinearRegression()
lr.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([1.07960155, 0.02848586, 0.02621369])

# %%
y_pred_train = lr.predict(X_train)
y_pred_val = lr.predict(X_val)

# %%
y_pred_train_01 = (y_pred_train>0.5).astype(int)
y_pred_val_01 = (y_pred_val>0.5).astype(int)

# %%
confusion_matrix(y_train, y_pred_train_01)[0]
# Out:
# array([1547,   45], dtype=int64)

# %%
fig, ax = plt.subplots(1,2, figsize=(20,6))
ConfusionMatrixDisplay(confusion_matrix(y_train, y_pred_train_01)).plot(ax=ax[0], cmap='Blues');
ax[0].set_title('TRAIN')
ConfusionMatrixDisplay(confusion_matrix(y_val, y_pred_val_01)).plot(ax=ax[1], cmap='Blues');
ax[1].set_title('VAL')
plt.show()

# %%
print('Accuracy: ')
print('Train  : ', accuracy_score(y_train, y_pred_train_01))
print('Val    : ', accuracy_score(y_val, y_pred_val_01))
print('Precision: ')
print('Train  : ', precision_score(y_train, y_pred_train_01))
print('Val    : ', precision_score(y_val, y_pred_val_01))
print('Recall: ')
print('Train  : ', recall_score(y_train, y_pred_train_01))
print('Val    : ', recall_score(y_val, y_pred_val_01))
# Out:
# Accuracy:
# Train  :  0.9703125
# Val    :  0.96875
# Precision:
# Train  :  0.9719276356830941
# Val    :  0.9688311688311688
# Recall:
# Train  :  0.9689054726368159
# Val    :  0.966321243523316

# %% [markdown]
# Линейная регрессия с порогом дает неплохой результат.

# %% [markdown]
# Сделаем предсказание для тестовой выборки и отправим результат

# %%
df_test[features].head()
# Out:
#    0-1_mean  forehead_width_norm  forehead_height_cm_norm
# 0      0.75            -1.247808                 0.283943
# 1      0.25             0.739315                -1.009317
# 2      1.00            -1.247808                 0.653446
# 3      0.75             1.100610                 0.283943
# 4      0.00             0.287696                -0.085560

# %%
y_pred = lr.predict(df_test[features].values)
y_pred
# Out:
# array([0.74348601, 0.22638904, 1.02307243, ..., 0.75604788, 1.08830486,
#        1.05576515])

# %%
df_test_result = df_test.copy()
df_test_result['gender_0-1'] = (y_pred>0.5).astype(int)
df_test_result['gender_result'] = df_test_result['gender_0-1'].replace({0: 'Female', 1: 'Male'})

# %%
answer = df_test_result['gender_result'].values
answer
# Out:
# array(['Male', 'Female', 'Male', ..., 'Male', 'Male', 'Male'],
#       dtype=object)

# %%
df_test_result['gender_result'].to_csv("answer.csv", header=None, index=None)

# %% [markdown]
# <img src='gender_final.PNG'>
